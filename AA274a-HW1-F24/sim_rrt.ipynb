# %% [markdown]
# # RRT Sampling-Based Motion Planning

# %%
# The autoreload extension will automatically load in new code as you edit files, 
# so you don't need to restart the kernel every time
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
from P2_rrt import *

plt.rcParams['figure.figsize'] = [8, 8] # Change default figure size
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Set up workspace

# %%
MAZE = np.array([
    ((10,10), ( 0,10)),
    (( 0,10), ( 0, 0)),
    (( 0, 0), (10, 0)),
    ((10, 0), (10,10)),

    (( 4, 3), ( 4, 2)),
    (( 4, 3), ( 2, 3)),
    (( 2, 2), ( 2, 3)),
    (( 2, 2), ( 4, 2)),

    (( 8, 8), ( 6, 8)),
    (( 8, 8), ( 8, 7)),
    (( 6, 7), ( 6, 8)),
    (( 6, 7), ( 8, 7)),
    
    (( 8, 5), ( 6, 5)),
    (( 8, 5), ( 8, 3)),
    (( 6, 3), ( 6, 5)),
    (( 6, 3), ( 8, 3)),
    
    (( 4, 7), ( 4, 5)),
    (( 4, 7), ( 2, 7)),
    (( 2, 5), ( 2, 7)),
    (( 2, 5), ( 4, 5))
])

# try changing these!
x_init = [1,9] # reset to [1,9] when saving results for submission
x_goal = [9,1] # reset to [9,1] when saving results for submission

# %% [markdown]
# ## Geometric Planning

# %%
grrt = GeometricRRT([0,0], [10,10], x_init, x_goal, MAZE)
grrt.solve(1.0, 2000)
# Out:
# found path!
# V: [[1.         9.        ]
#  [1.97599443 8.78220452]
#  [2.55609386 7.96765885]
#  ...
#  [0.         0.        ]
#  [0.         0.        ]
#  [0.         0.        ]]
# V[index]: [8.54210711 1.52832788]
# V[index]: [7.85559591 0.80120865]
# V[index]: [6.96848299 1.2627611 ]
# V[index]: [5.98160545 1.10129058]
# V[index]: [5.66979297 1.28691381]
# V[index]: [6.05772573 2.20860149]
# V[index]: [5.84895824 3.18656679]
# V[index]: [5.9151628  4.18437286]
# V[index]: [5.89110648 5.18408347]
# V[index]: [5.35922652 6.03090323]
# V[index]: [4.5830881  6.66146579]
# V[index]: [4.06195516 7.51494131]
# V[index]: [3.13111328 7.14951909]
# V[index]: [2.55609386 7.96765885]
# V[index]: [1.97599443 8.78220452]
# [array([8.54210711, 1.52832788]), array([7.85559591, 0.80120865]), array([6.96848299, 1.2627611 ]), array([5.98160545, 1.10129058]), array([5.66979297, 1.28691381]), array([6.05772573, 2.20860149]), array([5.84895824, 3.18656679]), array([5.9151628 , 4.18437286]), array([5.89110648, 5.18408347]), array([5.35922652, 6.03090323]), array([4.5830881 , 6.66146579]), array([4.06195516, 7.51494131]), array([3.13111328, 7.14951909]), array([2.55609386, 7.96765885]), array([1.97599443, 8.78220452])]
# True

# %% [markdown]
# ### Adding shortcutting

# %%
grrt.solve(1.0, 2000, shortcut=True)
# Out:
# found path!
# V: [[1.         9.        ]
#  [1.20068302 8.02034377]
#  [1.09239727 7.02622396]
#  ...
#  [0.         0.        ]
#  [0.         0.        ]
#  [0.         0.        ]]
# V[index]: [8.97986541 1.31449134]
# V[index]: [8.68372667 1.72234626]
# V[index]: [8.28264512 2.63838861]
# V[index]: [7.37911975 2.20985399]
# V[index]: [6.57774396 2.80801521]
# V[index]: [5.65388816 2.42527449]
# V[index]: [5.05986907 3.22972544]
# V[index]: [4.56946834 4.1012225 ]
# V[index]: [4.47572888 5.09681926]
# V[index]: [5.31957834 5.63339926]
# V[index]: [5.34945086 6.63295298]
# V[index]: [4.80560145 7.47213581]
# V[index]: [4.13991029 8.21836317]
# V[index]: [3.15842283 8.40988958]
# V[index]: [2.1917045 8.1540465]
# V[index]: [1.20068302 8.02034377]
# [array([8.97986541, 1.31449134]), array([8.68372667, 1.72234626]), array([8.28264512, 2.63838861]), array([7.37911975, 2.20985399]), array([6.57774396, 2.80801521]), array([5.65388816, 2.42527449]), array([5.05986907, 3.22972544]), array([4.56946834, 4.1012225 ]), array([4.47572888, 5.09681926]), array([5.31957834, 5.63339926]), array([5.34945086, 6.63295298]), array([4.80560145, 7.47213581]), array([4.13991029, 8.21836317]), array([3.15842283, 8.40988958]), array([2.1917045, 8.1540465]), array([1.20068302, 8.02034377])]
# index: 0
# index: 1
# index: 2
# index: 3
# index: 4
# index: 5
# index: 6
# index: 7
# index: 8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 grrt.solve(1.0, 2000, shortcut=True)
#
# File ~/AA274a-HW1-F24/P2_rrt.py:145, in RRT.solve(self, eps, max_iters, goal_bias, shortcut)
#     143 if shortcut:
#     144     self.plot_path(color="purple", linewidth=2, label="Original solution path")
# --> 145     self.shortcut_path()
#     146     self.plot_path(color="green", linewidth=2, label="Shortcut solution path")
#     147 else:
#
# File ~/AA274a-HW1-F24/P2_rrt.py:181, in RRT.shortcut_path(self)
#     179 print("index:", next((i for i, val in enumerate(self.path) if np.all(val == x)), -1))
#     180 x_parent = self.path[next((i for i, val in enumerate(self.path) if np.all(val == x)), -1)-1] # SHOULD BE INDEX OF X !!!
# --> 181 x_child =  self.path[next((i for i, val in enumerate(self.path) if np.all(val == x)), -1)+1] # SHOULD BE INDEX OF X !!!
#     182 if self.is_free_motion(self.obstacles, x_parent, x_child):
#     183     self.path.pop(next((i for i, val in enumerate(self.path) if np.all(val == x)), -1)) # SHOULD BE INDEX OF X !!!
#
# IndexError: list index out of range
